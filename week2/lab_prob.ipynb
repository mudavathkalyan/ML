# %%
# # Exercise Questions:

# 1. Read top five values
# 2. Print dataframe info_data types of each column
# 3. Print number of rows and columns
# 4. Drop duplicate rows_if any
# 5. Print number of rows and columns after dropping duplicates
# 6. Print summary statistics for numerical variables
# 7. Print number of missing values in each column
# 8. Drop the column with most missing values
# 9. Drop the rows with categorical missing values
# 10. Import the rows with numerical missing values
# 11. Sort the data w.r.t price_find the details of the most and the least expensive cars
# 12. Write a function to find min and max values of any column
# 13. Call the above function to find min max of horse power, length, fuel efficiency
# 14. Plot histogram of continuous numerical variable : price,sales,hoursepower,fuelefficiency
# 15. Probability density distribution of continuous numerical variable-length
# 16. Count by category –group by manufacture
# 17. Select all numerical variables
# 18. Print correlation coefficient value of price and sales
# 19. Plot correlation of price and sales using scatterplot
# 20.Pair plot
# 21. Boxplot of sales of different manufacturer
# 22. Boxplot of other numerical variables w.r.t manufacture
# 23. Divide the data into input and output y=sales in thousand, x=all other variables
# 24. Encode other categorical variables using label encoder
# 25. Encode categorical variable vehicle type using one-hot encoder
# 26.Split the data set into train and test set 70% train set 10% test set
# 27. Apply feature scaling on numerical variables

# %%
#codes

# %%
import pandas as pd
import matplotlib.pyplot  as plt

# %%
df=pd.read_csv("Car_sales.csv")
df2=pd.read_csv("Car_sales.csv")

# %%
# 1. Read top five values
df.head()
# Out:
#     Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0  Acura          Integra                        16.919               16.36
# 1  Acura          TL                             39.384              19.875
# 2  Acura          CL                             14.114              18.225
# 3  Acura          RL                              8.588              29.725
# 4  Audi           A4                             20.397              22.255
#
#   Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0    Passenger               21.5         1.8        140     101.2  67.3
# 1    Passenger               28.4         3.2        225     108.1  70.3
# 2    Passenger                  .         3.2        225     106.9  70.6
# 3    Passenger                 42         3.5        210     114.6  71.4
# 4    Passenger              23.99         1.8        150     102.6  68.2
#
#   Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 0  172.4       2.639          13.2              28      2-Feb-14
# 1  192.9       3.517          17.2              25      6-Mar-15
# 2    192        3.47          17.2              26      1-Apr-14
# 3  196.6        3.85            18              22      3-Oct-15
# 4    178       2.998          16.4              27     10-Aug-15

# %%
# 2. Print dataframe info_data types of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales in thousands   157 non-null    float64
#  3   4-year resale value  157 non-null    object
#  4   Vehicle type         157 non-null    object
#  5   Price in thousands   157 non-null    object
#  6   Engine size          157 non-null    object
#  7   Horsepower           157 non-null    object
#  8   Wheelbase            157 non-null    object
#  9   Width                157 non-null    object
#  10  Length               157 non-null    object
#  11  Curb weight          157 non-null    object
#  12  Fuel capacity        157 non-null    object
#  13  Fuel efficiency      157 non-null    object
#  14  Latest Launch        157 non-null    object
# dtypes: float64(1), object(14)
# memory usage: 18.5+ KB

# %%
# 3. Print number of rows and columns
df.shape
# Out:
# (157, 15)

# %%
df.shape[0]
# Out:
# 157

# %%
# 4. Drop duplicate rows_if any
df_cleaned = df.drop_duplicates()
df_cleaned
# Out:
#       Manufacturer              Model  Sales in thousands 4-year resale value  \
# 0    Acura          Integra                        16.919               16.36
# 1    Acura          TL                             39.384              19.875
# 2    Acura          CL                             14.114              18.225
# 3    Acura          RL                              8.588              29.725
# 4    Audi           A4                             20.397              22.255
# ..             ...                ...                 ...                 ...
# 152  Volvo          V40                             3.545                   .
# 153  Volvo          S70                            15.245                   .
# 154  Volvo          V70                            17.531                   .
# 155  Volvo          C70                             3.493                   .
# 156  Volvo          S80                            18.969                   .
#
#     Vehicle type Price in thousands Engine size Horsepower Wheelbase Width  \
# 0      Passenger               21.5         1.8        140     101.2  67.3
# 1      Passenger               28.4         3.2        225     108.1  70.3
# 2      Passenger                  .         3.2        225     106.9  70.6
# 3      Passenger                 42         3.5        210     114.6  71.4
# 4      Passenger              23.99         1.8        150     102.6  68.2
# ..           ...                ...         ...        ...       ...   ...
# 152    Passenger               24.4         1.9        160     100.5  67.6
# 153    Passenger               27.5         2.4        168     104.9  69.3
# 154    Passenger               28.8         2.4        168     104.9  69.3
# 155    Passenger               45.5         2.3        236     104.9  71.5
# 156    Passenger                 36         2.9        201     109.9  72.1
#
#     Length Curb weight Fuel capacity Fuel efficiency Latest Launch
# 0    172.4       2.639          13.2              28      2-Feb-14
# 1    192.9       3.517          17.2              25      6-Mar-15
# 2      192        3.47          17.2              26      1-Apr-14
# 3    196.6        3.85            18              22      3-Oct-15
# 4      178       2.998          16.4              27     10-Aug-15
# ..     ...         ...           ...             ...           ...
# 152  176.6       3.042          15.8              25     21-Sep-15
# 153  185.9       3.208          17.9              25     24-Nov-14
# 154  186.2       3.259          17.9              25     25-Jun-15
# 155  185.7       3.601          18.5              23     26-Apr-15
# 156  189.8         3.6          21.1              24     14-Nov-15
#
# [157 rows x 15 columns]

# %%
# 5. Print number of rows and columns after dropping duplicates
# print(df_cleaned)
print("Rows:", df_cleaned.shape[0], "Columns:", df_cleaned.shape[1])
# Out:
# Rows: 157 Columns: 15

# %%
# 6. Print summary statistics for numerical variables
df.describe()
# Out:
#        Sales in thousands
# count          157.000000
# mean            52.998076
# std             68.029422
# min              0.110000
# 25%             14.114000
# 50%             29.450000
# 75%             67.956000
# max            540.561000

# %%
# 7. Print number of missing values in each column
df.isnull().sum()
# Out:
# Manufacturer           0
# Model                  0
# Sales in thousands     0
# 4-year resale value    0
# Vehicle type           0
# Price in thousands     0
# Engine size            0
# Horsepower             0
# Wheelbase              0
# Width                  0
# Length                 0
# Curb weight            0
# Fuel capacity          0
# Fuel efficiency        0
# Latest Launch          0
# dtype: int64

# %%
# 8. Drop the column with most missing values
most_missing_col=df.isnull().sum().idxmax()
df.drop(columns=[most_missing_col],inplace=True)
print("\nDropped column with most missing values:", most_missing_col)
print(df.shape)
# Out:
# Dropped column with most missing values: Manufacturer
# (157, 14)

# %%
# 9. Drop the rows with categorical missing values
df.dropna(subset=df.select_dtypes(include=['object']).columns, inplace=True)

# %%
df.shape
# Out:
# (157, 14)

# %%
allCols=list(df.columns)

for cols in allCols:
    df[cols]=pd.to_numeric(df[cols],errors='coerce')

# %%
df.info() ###### se convertion object to numeric
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Model                0 non-null      float64
#  1   Sales in thousands   157 non-null    float64
#  2   4-year resale value  121 non-null    float64
#  3   Vehicle type         0 non-null      float64
#  4   Price in thousands   155 non-null    float64
#  5   Engine size          156 non-null    float64
#  6   Horsepower           156 non-null    float64
#  7   Wheelbase            156 non-null    float64
#  8   Width                156 non-null    float64
#  9   Length               156 non-null    float64
#  10  Curb weight          155 non-null    float64
#  11  Fuel capacity        156 non-null    float64
#  12  Fuel efficiency      154 non-null    float64
#  13  Latest Launch        0 non-null      float64
# dtypes: float64(14)
# memory usage: 17.3 KB

# %%
# 10. Import the rows with numerical missing values
numerical_df = df.select_dtypes(include=[np.number])
numerical_missing_rows = df[numerical_df.isnull().any(axis=1)]
numerical_missing_rows
# Out:
#      Model  Sales in thousands  4-year resale value  Vehicle type  \
# 0      NaN              16.919               16.360           NaN
# 1      NaN              39.384               19.875           NaN
# 2      NaN              14.114               18.225           NaN
# 3      NaN               8.588               29.725           NaN
# 4      NaN              20.397               22.255           NaN
# ..     ...                 ...                  ...           ...
# 152    NaN               3.545                  NaN           NaN
# 153    NaN              15.245                  NaN           NaN
# 154    NaN              17.531                  NaN           NaN
# 155    NaN               3.493                  NaN           NaN
# 156    NaN              18.969                  NaN           NaN
#
#      Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# 2                   NaN          3.2       225.0      106.9   70.6   192.0
# 3                 42.00          3.5       210.0      114.6   71.4   196.6
# 4                 23.99          1.8       150.0      102.6   68.2   178.0
# ..                  ...          ...         ...        ...    ...     ...
# 152               24.40          1.9       160.0      100.5   67.6   176.6
# 153               27.50          2.4       168.0      104.9   69.3   185.9
# 154               28.80          2.4       168.0      104.9   69.3   186.2
# 155               45.50          2.3       236.0      104.9   71.5   185.7
# 156               36.00          2.9       201.0      109.9   72.1   189.8
#
#      Curb weight  Fuel capacity  Fuel efficiency  Latest Launch
# 0          2.639           13.2             28.0            NaN
# 1          3.517           17.2             25.0            NaN
# 2          3.470           17.2             26.0            NaN
# 3          3.850           18.0             22.0            NaN
# 4          2.998           16.4             27.0            NaN
# ..           ...            ...              ...            ...
# 152        3.042           15.8             25.0            NaN
# 153        3.208           17.9             25.0            NaN
# 154        3.259           17.9             25.0            NaN
# 155        3.601           18.5             23.0            NaN
# 156        3.600           21.1             24.0            NaN
#
# [157 rows x 14 columns]

# %%
# 11. Sort the data w.r.t price_find the details of the most and the least expensive cars
df_sorted_price = df.sort_values(by='Price in thousands', ascending=False)
most_expensive = df_sorted_price.iloc[0]
least_expensive = df_sorted_price.iloc[-1]

print("Most Expensive Car:\n", most_expensive)
print("\nLeast Expensive Car:\n", least_expensive)
# Out:
# Most Expensive Car:
#  Model                      NaN
# Sales in thousands       0.954
# 4-year resale value        NaN
# Vehicle type               NaN
# Price in thousands      85.500
# Engine size              5.000
# Horsepower             302.000
# Wheelbase              113.600
# Width                   73.100
# Length                 196.600
# Curb weight              4.115
# Fuel capacity           23.200
# Fuel efficiency         20.000
# Latest Launch              NaN
# Name: 99, dtype: float64
#
# Least Expensive Car:
#  Model                    NaN
# Sales in thousands     53.48
# 4-year resale value    19.54
# Vehicle type             NaN
# Price in thousands       NaN
# Engine size              NaN
# Horsepower               NaN
# Wheelbase                NaN
# Width                    NaN
# Length                   NaN
# Curb weight              NaN
# Fuel capacity            NaN
# Fuel efficiency          NaN
# Latest Launch            NaN
# Name: 33, dtype: float64

# %%
df
# Out:
#      Model  Sales in thousands  4-year resale value  Vehicle type  \
# 0      NaN              16.919               16.360           NaN
# 1      NaN              39.384               19.875           NaN
# 2      NaN              14.114               18.225           NaN
# 3      NaN               8.588               29.725           NaN
# 4      NaN              20.397               22.255           NaN
# ..     ...                 ...                  ...           ...
# 152    NaN               3.545                  NaN           NaN
# 153    NaN              15.245                  NaN           NaN
# 154    NaN              17.531                  NaN           NaN
# 155    NaN               3.493                  NaN           NaN
# 156    NaN              18.969                  NaN           NaN
#
#      Price in thousands  Engine size  Horsepower  Wheelbase  Width  Length  \
# 0                 21.50          1.8       140.0      101.2   67.3   172.4
# 1                 28.40          3.2       225.0      108.1   70.3   192.9
# 2                   NaN          3.2       225.0      106.9   70.6   192.0
# 3                 42.00          3.5       210.0      114.6   71.4   196.6
# 4                 23.99          1.8       150.0      102.6   68.2   178.0
# ..                  ...          ...         ...        ...    ...     ...
# 152               24.40          1.9       160.0      100.5   67.6   176.6
# 153               27.50          2.4       168.0      104.9   69.3   185.9
# 154               28.80          2.4       168.0      104.9   69.3   186.2
# 155               45.50          2.3       236.0      104.9   71.5   185.7
# 156               36.00          2.9       201.0      109.9   72.1   189.8
#
#      Curb weight  Fuel capacity  Fuel efficiency  Latest Launch
# 0          2.639           13.2             28.0            NaN
# 1          3.517           17.2             25.0            NaN
# 2          3.470           17.2             26.0            NaN
# 3          3.850           18.0             22.0            NaN
# 4          2.998           16.4             27.0            NaN
# ..           ...            ...              ...            ...
# 152        3.042           15.8             25.0            NaN
# 153        3.208           17.9             25.0            NaN
# 154        3.259           17.9             25.0            NaN
# 155        3.601           18.5             23.0            NaN
# 156        3.600           21.1             24.0            NaN
#
# [157 rows x 14 columns]

# %%
# 12
def find_min_max(df, column):
    return df[column].min(), df[column].max()


find_min_max(df,"Horsepower")
# Out:
# (55.0, 450.0)

# %%
# 13
print("Horsepower:", find_min_max(df, 'Horsepower'))
print("Length:", find_min_max(df, 'Length'))
print("Fuel Efficiency:", find_min_max(df, 'Fuel efficiency'))
# Out:
# Horsepower: (55.0, 450.0)
# Length: (149.4, 224.5)
# Fuel Efficiency: (15.0, 45.0)

# %%
#14. Plot histogram of continuous numerical variable :price,sales,hoursepower,fuelefficiency
df[['Price in thousands', 'Sales in thousands', 'Horsepower', 'Fuel efficiency']].hist(bins=20, figsize=(12, 8))
plt.show()

# %%
# 15. Probability density distribution of continuous numerical variable-length
import seaborn as sns

sns.kdeplot(df['Length'].dropna(), shade=True)
plt.title('Probability Density of Vehicle Length')
plt.show()
# Out:
# /tmp/ipykernel_14387/3756685761.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Length'].dropna(), shade=True)

# %%
# 16
df2.groupby('Manufacturer').size()
# Out:
# Manufacturer
# Acura             4
# Audi              3
# BMW               3
# Buick             4
# Cadillac          5
# Chevrolet         9
# Chrysler          7
# Dodge            11
# Ford             11
# Honda             5
# Hyundai           3
# Infiniti          1
# Jaguar            1
# Jeep              3
# Lexus             6
# Lincoln           3
# Mercedes-Benz     9
# Mercury           6
# Mitsubishi        7
# Nissan            7
# Oldsmobile        6
# Plymouth          4
# Pontiac           6
# Porsche           3
# Saab              2
# Saturn            5
# Subaru            2
# Toyota            9
# Volkswagen        6
# Volvo             6
# dtype: int64

# %%
# 17 Select all numerical variables

numerical_vars = df.select_dtypes(include=[np.number])
print(numerical_vars.columns)
# Out:
# Index(['Model', 'Sales in thousands', '4-year resale value', 'Vehicle type',
#        'Price in thousands', 'Engine size', 'Horsepower', 'Wheelbase', 'Width',
#        'Length', 'Curb weight', 'Fuel capacity', 'Fuel efficiency',
#        'Latest Launch'],
#       dtype='object')

# %%
# 18. Print correlation coefficient value of price and sales
sales=df['Sales in thousands']
price=df['Price in thousands']
price.corr(sales)
# Out:
# -0.3047344541294122

# %%
# 19. Plot correlation of price and sales using scatterplot
import seaborn as sn
sns.scatterplot(x=price,y=sales,data=df)
# Out:
# <Axes: xlabel='Price in thousands', ylabel='Sales in thousands'>

# %%
sns.pairplot(df[['Price in thousands', 'Sales in thousands', 'Horsepower', 'Fuel efficiency']])
plt.show()

# %%
sns.pairplot(df[['Price in thousands', 'Sales in thousands']])

# %%
# 21. Boxplot of sales of different manufacturer
plt.figure(figsize=(12, 6))
sns.boxplot(x='Manufacturer',y=sales,data=df2)
plt.xticks(rotation=90)
plt.show()

# %%
# 22
num_cols = ['Price in thousands', 'Horsepower', 'Length', 'Fuel efficiency']
for col in num_cols:
    plt.figure(figsize=(12, 6))
    sns.boxplot(x='Manufacturer', y=col, data=df2)
    plt.title(f'Boxplot of {col} by Manufacturer')
    plt.xticks(rotation=90)
    plt.show()

# %%
x=df2.drop('Sales in thousands' ,axis=1)
y=df2['Sales in thousands']

# %%
x
# Out:
#       Manufacturer              Model 4-year resale value Vehicle type  \
# 0    Acura          Integra                         16.36    Passenger
# 1    Acura          TL                             19.875    Passenger
# 2    Acura          CL                             18.225    Passenger
# 3    Acura          RL                             29.725    Passenger
# 4    Audi           A4                             22.255    Passenger
# ..             ...                ...                 ...          ...
# 152  Volvo          V40                                 .    Passenger
# 153  Volvo          S70                                 .    Passenger
# 154  Volvo          V70                                 .    Passenger
# 155  Volvo          C70                                 .    Passenger
# 156  Volvo          S80                                 .    Passenger
#
#     Price in thousands Engine size Horsepower Wheelbase Width Length  \
# 0                 21.5         1.8        140     101.2  67.3  172.4
# 1                 28.4         3.2        225     108.1  70.3  192.9
# 2                    .         3.2        225     106.9  70.6    192
# 3                   42         3.5        210     114.6  71.4  196.6
# 4                23.99         1.8        150     102.6  68.2    178
# ..                 ...         ...        ...       ...   ...    ...
# 152               24.4         1.9        160     100.5  67.6  176.6
# 153               27.5         2.4        168     104.9  69.3  185.9
# 154               28.8         2.4        168     104.9  69.3  186.2
# 155               45.5         2.3        236     104.9  71.5  185.7
# 156                 36         2.9        201     109.9  72.1  189.8
#
#     Curb weight Fuel capacity Fuel efficiency Latest Launch
# 0         2.639          13.2              28      2-Feb-14
# 1         3.517          17.2              25      6-Mar-15
# 2          3.47          17.2              26      1-Apr-14
# 3          3.85            18              22      3-Oct-15
# 4         2.998          16.4              27     10-Aug-15
# ..          ...           ...             ...           ...
# 152       3.042          15.8              25     21-Sep-15
# 153       3.208          17.9              25     24-Nov-14
# 154       3.259          17.9              25     25-Jun-15
# 155       3.601          18.5              23     26-Apr-15
# 156         3.6          21.1              24     14-Nov-15
#
# [157 rows x 14 columns]

# %%
y
# Out:
# 0      16.919
# 1      39.384
# 2      14.114
# 3       8.588
# 4      20.397
#         ...
# 152     3.545
# 153    15.245
# 154    17.531
# 155     3.493
# 156    18.969
# Name: Sales in thousands, Length: 157, dtype: float64

# %%
#24. Encode other categorical variables using label encoder
from sklearn.preprocessing import LabelEncoder
encod=LabelEncoder()
encod
# Out:
# LabelEncoder()

# %%
for col in x.select_dtypes(include='object').columns:
    x[col] = encod.fit_transform(x[col].astype(str))

# %%
# 25 Encode categorical variable vehicle type using one-hot encoder
x = pd.get_dummies(x, columns=['Vehicle type'], drop_first=True)

# %%
#26
from sklearn.model_selection import train_test_split
x_train,x_test,y_test,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
# 27 apply feature scalling on numerical variables

# %%
x=df.drop('Sales in thousands' ,axis=1)
y=df['Sales in thousands']
from sklearn.model_selection import train_test_split
x_train,x_test,y_test,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = x_train.copy()
X_test_scaled = x_test.copy()

# Identify numeric columns
numeric_cols = x.select_dtypes(include=[np.number]).columns

# Apply scaling
X_train_scaled[numeric_cols] = scaler.fit_transform(x_train[numeric_cols])
X_test_scaled[numeric_cols] = scaler.transform(x_test[numeric_cols])
# Out:
# /home/rgukt-basar/myenv/lib/python3.12/site-packages/sklearn/utils/extmath.py:1101: RuntimeWarning: invalid value encountered in divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# /home/rgukt-basar/myenv/lib/python3.12/site-packages/sklearn/utils/extmath.py:1106: RuntimeWarning: invalid value encountered in divide
#   T = new_sum / new_sample_count
# /home/rgukt-basar/myenv/lib/python3.12/site-packages/sklearn/utils/extmath.py:1126: RuntimeWarning: invalid value encountered in divide
#   new_unnormalized_variance -= correction**2 / new_sample_count

# %%
X_train_scaled.shape
# Out:
# (109, 13)

# %%
X_test_scaled.shape
# Out:
# (48, 13)
